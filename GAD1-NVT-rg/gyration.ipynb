# %%
from math import *
import matplotlib.pyplot as plt
import matplotlib._color_data as mcd
import matplotlib.pylab as pl
import numpy as n

# %%
gyration = []
#fig, ax = plt.plot(tight_layout=True)
for i in range(180, 310, 20):
    data = np.loadtxt("GAD1_gyrate_T%dK.xvg" %i, comments=["@", "#"],unpack=True)
    gyration = data[1]
    end_int = ceil(max(gyration)/0.05)
    begin_int = floor(min(gyration)/0.05)
    nbins= end_int-begin_int
    #y,x,_ = ax.hist(gyration, bins=nbins, range=[begin_int*0.05,end_int*0.05],ec='black',density=True)
    y,x,_ = plt.hist(gyration, bins=nbins,range=[begin_int*0.05,end_int*0.05],ec='black',density=True)
    plt.plot(x[0:-1]+0.025,y,linewidth=0.3,marker="o",markersize=1,color='k',label='T%dK' %i)

# %%
fig, ax = plt.plot(tight_layout=True)
y,x,_ = ax.hist(distance_skip[i],bins=nbins,range=[begin_int*0.05,end_int*0.05],ec='black',density=True)
# Out:
# [array([0.799854, 0.798706, 0.79953 , ..., 0.807105, 0.802282, 0.796177]),
#  array([0.805186, 0.798038, 0.797356, ..., 0.809893, 0.801769, 0.806129]),
#  array([0.796674, 0.799844, 0.795528, ..., 0.803021, 0.799785, 0.795588]),
#  array([0.804714, 0.808814, 0.819064, ..., 0.834988, 0.828265, 0.835726]),
#  array([0.80042 , 0.783395, 0.801041, ..., 0.971309, 0.93798 , 0.952092]),
#  array([0.80451 , 0.803228, 0.799309, ..., 0.831934, 0.826312, 0.818251]),
#  array([0.799317, 0.816445, 0.80718 , ..., 0.918248, 0.877215, 0.925519])]

# %%
# Out:
# 180
# 200
# 220
# 240
# 260
# 280
# 300

# %%
data = np.array([1,2,3])
data.
